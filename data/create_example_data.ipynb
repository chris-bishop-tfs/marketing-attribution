# %% [markdown]
# ### Overview
#
# We create an example dataset from a [publicly available dataset](https://www.kaggle.com/datasets/frtgnn/dunnhumby-the-complete-journey). Note that these data are for demonstrative purposes only and the specifics are not intended for generalized applications.
#
# For example, the window to value mapping is messy and over estimates total value of the original dataset.
#
# The exported data are intended to be self-contained on their own. If users have questions regarding proper window creation etc., please contact the authors directly.

# %% [markdown]
# ### Data Preamble
#
# - Download [Dunnhumby](https://www.kaggle.com/datasets/frtgnn/dunnhumby-the-complete-journey) data set and extract to a `data` subdirectory.
# - Build and launch the provided Docker image.
# - Execute the following notebook from either the container's terminal or Jupyter Notebook (localhost:8888)
#
# This will generate a JSON file that can be read and used directly in subsequent analyes/demonstrations.

# %%
# Databricks notebook source
# Import libraries
import datetime
import pandas as pd
import pyspark.sql.functions as sf
from pyspark.sql.window import Window
from dateutil.relativedelta import relativedelta
from pyspark.sql import SparkSession

# SPARK
spark = (
    SparkSession
    .builder
    .getOrCreate()
)

# We'll allow for lagging effects, such as a campaign having effects after the campaign ends
# The value here is arbitrary, the user can change this at their discretion
N_RESPONSE_DAYS = 90

# Start date is arbitrary, just wanted something more "human-readable"
START_DATE = datetime.date(2020, 1, 1)

# UDF to convert number of days to a calendar date
days_to_date = sf.udf(lambda x: START_DATE + relativedelta(days=x-1), DateType())
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/usr/local/spark-3.1.2-bin-hadoop3.2/jars/spark-unsafe_2.12-3.1.2.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# 22/05/06 18:43:55 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/05/06 18:43:56 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
# Let's pull in some raw data
campaign_table = (
  spark
  .createDataFrame(
    # Bishop cheated and used LameDas to do some reading
    pd.read_csv('data/campaign_table.csv')
  )
  .withColumnRenamed(
    'description',
    'campaign_type'
  )
  # Reduce description to A/B/C
  .withColumn(
    'campaign_type',
    sf.upper('campaign_type').substr(5, 1)
  )
  .withColumnRenamed(
    'campaign',
    'campaign_id'
  )
  .withColumnRenamed(
    'household_key',
    'household_id'
  )
).cache()

display(campaign_table.limit(10).toPandas())
# Out:
#   campaign_type  household_id  campaign_id
# 0             A            17           26
# 1             A            27           26
# 2             A           212           26
# 3             A           208           26
# 4             A           192           26
# 5             A           187           26
# 6             A           183           26
# 7             A           142           26
# 8             A           140           26
# 9             A           134           26

# %%
# Campaign descriptions
campaign_desc = (
  spark
  .createDataFrame(
    pd.read_csv('data/campaign_desc.csv')
  )
  .withColumnRenamed(
    'description',
    'campaign_type'
  )
  # Reduce description to A/B/C
  .withColumn(
    'campaign_type',
    sf.upper('campaign_type').substr(5, 1)
  )
  .withColumnRenamed(
    'start_day',
    'window_start'
  )
  .withColumnRenamed(
    'end_day',
    'window_end'
  )
  # Add in response time
  .withColumn(
    'window_end',
    sf.col('window_end') + sf.lit(N_RESPONSE_DAYS)
  )
  .withColumn(
    'window_start',
    days_to_date(sf.col('window_start'))
  )
  .withColumn(
    'window_end',
    days_to_date(sf.col('window_end'))
  )
#   # Arbitrary start date for demonstrative purposes
#   .withColumn(
#     '_start_date',
#     sf.lit(datetime.date(2020, 1, 1))
#   )
#   .withColumn(
#     'transaction_day',
#     # EXPR required here, see https://issues.apache.org/jira/browse/SPARK-26393
#     sf.expr(
#       "date_add(_start_date, day - 1)"
#     )
#   )
  .withColumnRenamed(
    'campaign',
    'campaign_id'
  )
  .select(
    'campaign_id',
    'campaign_type',
    'window_start',
    'window_end'
  )
  .orderBy(
    'campaign_id'
  )
).cache()

display(campaign_desc.limit(10).toPandas())
# Out:
#    campaign_id campaign_type window_start  window_end
# 0            1             B   2020-12-11  2021-04-17
# 1            2             B   2020-12-16  2021-04-17
# 2            3             C   2020-12-21  2021-05-16
# 3            4             B   2021-01-06  2021-05-08
# 4            5             B   2021-01-11  2021-05-15
# 5            6             C   2021-01-27  2021-05-29
# 6            7             B   2021-02-01  2021-06-05
# 7            8             A   2021-02-15  2021-07-03
# 8            9             B   2021-03-10  2021-07-10
# 9           10             B   2021-04-07  2021-08-07

# %%
# Sales data
transaction_data = (
  spark
  .createDataFrame(
    pd.read_csv('data/transaction_data.csv')
  )
  .withColumn(
    'day',
    sf.col('day').cast('integer')
  )
  .withColumnRenamed(
    'household_key',
    'household_id'
  )
  .withColumnRenamed(
    'sales_value',
    'revenue_usd'
  )
  .withColumn(
    'transaction_day',
    days_to_date(sf.col('day'))
  )
).cache()

display(transaction_data.limit(10).toPandas())
# Out:
# 22/05/06 18:46:18 WARN TaskSetManager: Stage 8 contains a task of very large size (13913 KiB). The maximum recommended task size is 1000 KiB.
#    household_id    BASKET_ID  day  PRODUCT_ID  QUANTITY  revenue_usd  \
# 0          2375  26984851472    1     1004906         1         1.39
# 1          2375  26984851472    1     1033142         1         0.82
# 2          2375  26984851472    1     1036325         1         0.99
# 3          2375  26984851472    1     1082185         1         1.21
# 4          2375  26984851472    1     8160430         1         1.50
# 5          2375  26984851516    1      826249         2         1.98
# 6          2375  26984851516    1     1043142         1         1.57
# 7          2375  26984851516    1     1085983         1         2.99
# 8          2375  26984851516    1     1102651         1         1.89
# 9          2375  26984851516    1     6423775         1         2.00
#
#    STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC  \
# 0       364        -0.60        1631        1          0.0                0.0
# 1       364         0.00        1631        1          0.0                0.0
# 2       364        -0.30        1631        1          0.0                0.0
# 3       364         0.00        1631        1          0.0                0.0
# 4       364        -0.39        1631        1          0.0                0.0
# 5       364        -0.60        1642        1          0.0                0.0
# 6       364        -0.68        1642        1          0.0                0.0
# 7       364        -0.40        1642        1          0.0                0.0
# 8       364         0.00        1642        1          0.0                0.0
# 9       364        -0.79        1642        1          0.0                0.0
#
#   transaction_day
# 0      2020-01-01
# 1      2020-01-01
# 2      2020-01-01
# 3      2020-01-01
# 4      2020-01-01
# 5      2020-01-01
# 6      2020-01-01
# 7      2020-01-01
# 8      2020-01-01
# 9      2020-01-01

# %%
# Only need daily-level granularity for this toy example
transaction_summary = (
  transaction_data
  .groupBy(
    'household_id',
    'transaction_day'
  )
  .agg(
    sf.sum('revenue_usd').alias('revenue_usd')
  )
  .orderBy(
    'household_id',
    'transaction_day'
  )
).cache()

display(transaction_summary.limit(10).toPandas())
# Out:
# 22/05/06 18:46:21 WARN TaskSetManager: Stage 9 contains a task of very large size (13913 KiB). The maximum recommended task size is 1000 KiB.
#    household_id transaction_day  revenue_usd
# 0             1      2020-02-20        78.66
# 1             1      2020-03-07        41.10
# 2             1      2020-03-28        26.90
# 3             1      2020-04-03        63.43
# 4             1      2020-04-10        53.45
# 5             1      2020-04-17        26.76
# 6             1      2020-04-20        23.55
# 7             1      2020-05-07       110.34
# 8             1      2020-05-16        87.44
# 9             1      2020-05-25        73.32

# %%
# Let's see if we have overlapping campaigns
master_campaign = (
  campaign_table
  .join(
    campaign_desc.select('campaign_id', 'window_start', 'window_end'),
    how='left',
    on='campaign_id'
  )
  # We need to determine if there is OVERLAP between campaigns of the same type
  # If so, then consolidate into a single record. This will make the window
  # creation logic easier below.
  .withColumn(
    'window_end_lag',
    sf.lag('window_end').over(
      Window()
      .partitionBy(
        'household_id',
        'campaign_type'
      )
      .orderBy(
        'window_start'
      )
    )
  )
  # Does the previous campaign end AFTER the next campaign begins?
  .withColumn(
    'is_overlap',
    sf.col('window_end_lag') >= sf.col('window_start')
  )
  .withColumn(
    'campaign_type_lag',
    sf.lag('campaign_type').over(
      Window()
      .partitionBy(
        'household_id'
      )
      .orderBy(
        'window_start'
      )
    )
  )
  .withColumn(
    'is_diff_type',
    sf.col('campaign_type_lag') != sf.col('campaign_type')
  )
  .fillna(
    False,
    subset=['is_overlap', 'is_diff_type']
  )
  .withColumn(
    'is_new_window',
    (
      (~sf.col('is_overlap')) |
      (
        sf.col('is_overlap') &
        sf.col('is_diff_type')
      )
    )
  )
  # Add in a campaign_record_id
  .withColumn(
    'campaign_record_id',
    sf.sum((sf.col('is_new_window')).cast('integer')).over(
      Window()
      .orderBy(
        'household_id',
        'window_start'
      )
      .rowsBetween(
        Window.unboundedPreceding,
        0
      )
    )
  )
  .orderBy(
    'household_id',
    'window_start'
  )
).cache()

display(master_campaign.limit(10).toPandas())
# Out:
# 22/05/06 18:46:32 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
#    campaign_id campaign_type  household_id window_start  window_end  \
# 0           29             B             1   2020-10-07  2021-02-27
# 1            8             A             1   2021-02-15  2021-07-03
# 2           12             B             1   2021-04-21  2021-08-21
# 3           13             A             1   2021-05-18  2021-10-02
# 4           18             A             1   2021-08-09  2022-01-01
# 5           20             C             1   2021-09-06  2022-02-13
# 6           22             B             1   2021-09-15  2022-01-15
# 7           23             B             1   2021-10-07  2022-02-12
# 8           18             A             2   2021-08-09  2022-01-01
# 9            8             A             3   2021-02-15  2021-07-03
#
#   window_end_lag  is_overlap campaign_type_lag  is_diff_type  is_new_window  \
# 0           None       False              None         False           True
# 1           None       False                 B          True           True
# 2     2021-02-27       False                 A          True           True
# 3     2021-07-03        True                 B          True           True
# 4     2021-10-02        True                 A         False          False
# 5           None       False                 A          True           True
# 6     2021-08-21       False                 C          True           True
# 7     2022-01-15        True                 B         False          False
# 8           None       False              None         False           True
# 9           None       False              None         False           True
#
#    campaign_record_id
# 0                   1
# 1                   2
# 2                   3
# 3                   4
# 4                   4
# 5                   5
# 6                   6
# 7                   6
# 8                   7
# 9                   8

# %%
# Consolidate campaign_records so we have a single record per time slot/campaign type
# This makes window creation simpler below.
master_campaign = (
  master_campaign
  .groupBy(
    'campaign_record_id',
    'household_id',
    'campaign_type'
  )
  .agg(
    sf.min('window_start').alias('window_start'),
    sf.max('window_end').alias('window_end')
  )
).cache()

# Spot check with a household_id we know has some overlapping campaign_types
display(
    master_campaign
    .filter(sf.col('household_id') == 1)
    .orderBy('window_start')
    .limit(10)
    .toPandas()
)
# Out:
#    campaign_record_id  household_id campaign_type window_start  window_end
# 0                   1             1             B   2020-10-07  2021-02-27
# 1                   2             1             A   2021-02-15  2021-07-03
# 2                   3             1             B   2021-04-21  2021-08-21
# 3                   4             1             A   2021-05-18  2022-01-01
# 4                   5             1             C   2021-09-06  2022-02-13
# 5                   6             1             B   2021-09-15  2022-02-12

# %%
# Let's build our "treatment" windows for attribution purposes
window_map = (
  master_campaign.alias('a')
  .join(
    master_campaign.alias('b'),
    on=(
      (
        sf.col('b.window_start').between(sf.col('a.window_start'), sf.col('a.window_end'))
      ) &
      (
        sf.col('a.household_id') == sf.col('b.household_id')
      )
    )
  )
  .select(
    'a.household_id',
    sf.col('a.campaign_record_id').alias('window_id'),
    'a.window_start',
    'a.window_end',
    'b.campaign_record_id',
    'b.campaign_type'
  )
  # We'll assign a new 'player_id' column to conform to package requirements
  .withColumn(
    'treatment',
    sf.col('campaign_type')
  )
  .orderBy(
    'window_id',
    'window_start'
  )
).cache()

display(window_map.limit(10).toPandas())
# Out:
#    household_id  window_id window_start  window_end  campaign_record_id  \
# 0             1          1   2020-10-07  2021-02-27                   1
# 1             1          1   2020-10-07  2021-02-27                   2
# 2             1          2   2021-02-15  2021-07-03                   2
# 3             1          2   2021-02-15  2021-07-03                   3
# 4             1          2   2021-02-15  2021-07-03                   4
# 5             1          3   2021-04-21  2021-08-21                   3
# 6             1          3   2021-04-21  2021-08-21                   4
# 7             1          4   2021-05-18  2022-01-01                   4
# 8             1          4   2021-05-18  2022-01-01                   5
# 9             1          4   2021-05-18  2022-01-01                   6
#
#   campaign_type treatment
# 0             B         B
# 1             A         A
# 2             A         A
# 3             B         B
# 4             A         A
# 5             B         B
# 6             A         A
# 7             A         A
# 8             C         C
# 9             B         B

# %%
# Now that we have the windows mapped, we need to pivot into a wide data frame for attribution
attribution_window = (
  window_map
  .groupBy(
    'household_id',
    'window_id',
    'window_start',
    'window_end'
  )
  .pivot(
    'treatment'
  )
  .count()
  .fillna(
    0,
    subset=treatments
  )
).cache()

# %%
# Convert player columns into boolean values
treatments = (
    window_map
    .select('treatment')
    .dropDuplicates()
    .toPandas()
    ['treatment']
    .tolist()
)

# Sort player_ids
treatments.sort()

# Convert to tuple
treatments = tuple(treatments)

display(treatments)
# Out:
# ('A', 'B', 'C')

# %%
display(window_map.limit(10).toPandas())
# Out:
#    household_id  window_id window_start  window_end  campaign_record_id  \
# 0             1          1   2020-10-07  2021-02-27                   1
# 1             1          1   2020-10-07  2021-02-27                   2
# 2             1          2   2021-02-15  2021-07-03                   2
# 3             1          2   2021-02-15  2021-07-03                   3
# 4             1          2   2021-02-15  2021-07-03                   4
# 5             1          3   2021-04-21  2021-08-21                   3
# 6             1          3   2021-04-21  2021-08-21                   4
# 7             1          4   2021-05-18  2022-01-01                   4
# 8             1          4   2021-05-18  2022-01-01                   5
# 9             1          4   2021-05-18  2022-01-01                   6
#
#   campaign_type treatment
# 0             B         B
# 1             A         A
# 2             A         A
# 3             B         B
# 4             A         A
# 5             B         B
# 6             A         A
# 7             A         A
# 8             C         C
# 9             B         B

# %%
treatment_data = (
    window_map
    .groupBy(
        'window_id'
    )
    # Don't need to maintain order in our case, so collect set is OK here
    .agg(
        sf.collect_set('treatment').alias('impressions')
    )
    .withColumnRenamed(
        'window_id',
        'identifier'
    )
).cache()


# # Convert impressions column to tuple
# treatment_data['impressions'] = treatment_data.impressions.apply(lambda x: tuple(x))

# treatment_data.head()
# display(treatment_data.limit(10).toPandas().to_dict(orient='records'))
# Out:
# 22/05/06 18:56:25 WARN CacheManager: Asked to cache already cached data.

# %%
# Now we need REVENUE per window
revenue_to_window = (
  attribution_window.select('household_id', 'window_id', 'window_start', 'window_end').alias('a')
  .join(
    transaction_summary.alias('b'),
    on=(
      sf.col('b.transaction_day').between(
        sf.col('a.window_start'),
        sf.col('a.window_end')
      ) &
      (
        sf.col('a.household_id') == sf.col('b.household_id')
      )
    ),
    how='left'
  )
  # Sum up revenue per window
  .groupBy(
    # Household_id here mostly for spot checking
#     'a.household_id',
    'window_id'
  )
  .agg(
    sf.sum('revenue_usd').alias('revenue_usd')
  )
  .fillna(
    0,
    subset=['revenue_usd']
  )
  # Truncate to dollars so I don't have to stare at floating point numbers
  .withColumn(
    'revenue_usd',
    sf.col('revenue_usd').cast('long')
  )
  .withColumnRenamed(
    'window_id',
    'identifier'
  )
).cache()

display(revenue_to_window.limit(10).toPandas())
# Out:
# [Stage 46:==============================================>      (176 + 12) / 200]
#    identifier  revenue_usd
# 0           1          944
# 1           2          952
# 2           3          776
# 3           4         1389
# 4           5          717
# 5           6          628
# 6           7          332
# 7           8          433
# 8           9          199
# 9          10           68

# %%
attribution_data = (
    treatment_data
    .join(
        revenue_to_window,
        on='identifier',
        how='left'
    )
    .withColumnRenamed(
        'revenue_usd',
        'value'
    )
    .toPandas()
)

attribution_data['impressions'] = attribution_data.impressions.apply(lambda x: tuple(x))

# Convert to JSON
attribution_data_json = attribution_data.to_dict(orient='records')

# %%
# Write to file
import json

with open('data/example_data.json', 'w') as f:
    json.dump(attribution_data_json, f)

# %%
with open('data/example_data.json', 'r') as f:
    x = json.load(f)

# %%
x
# Out:
# [{'identifier': 1, 'impressions': ['B', 'A'], 'value': 944},
#  {'identifier': 2, 'impressions': ['B', 'A'], 'value': 952},
#  {'identifier': 3, 'impressions': ['B', 'A'], 'value': 776},
#  {'identifier': 4, 'impressions': ['C', 'B', 'A'], 'value': 1389},
#  {'identifier': 5, 'impressions': ['C', 'B'], 'value': 717},
#  {'identifier': 6, 'impressions': ['B'], 'value': 628},
#  {'identifier': 7, 'impressions': ['A'], 'value': 332},
#  {'identifier': 8, 'impressions': ['C', 'A'], 'value': 433},
#  {'identifier': 9, 'impressions': ['C'], 'value': 199},
#  {'identifier': 10, 'impressions': ['A'], 'value': 68},
#  {'identifier': 11, 'impressions': ['B', 'A'], 'value': 1269},
#  {'identifier': 12, 'impressions': ['A'], 'value': 2635},
#  {'identifier': 13, 'impressions': ['B', 'A'], 'value': 1527},
#  {'identifier': 14, 'impressions': ['A'], 'value': 1079},
#  {'identifier': 15, 'impressions': ['B', 'A'], 'value': 1833},
#  {'identifier': 16, 'impressions': ['B', 'A'], 'value': 1020},
#  {'identifier': 17, 'impressions': ['B', 'A'], 'value': 972},
#  {'identifier': 18, 'impressions': ['B', 'A'], 'value': 1247},
#  {'identifier': 19, 'impressions': ['B', 'A'], 'value': 1459},
#  {'identifier': 20, 'impressions': ['B', 'A'], 'value': 1421},
#  {'identifier': 21, 'impressions': ['B'], 'value': 1147},
#  {'identifier': 22, 'impressions': ['B', 'A'], 'value': 2772},
#  {'identifier': 23, 'impressions': ['B', 'A'], 'value': 2702},
#  {'identifier': 24, 'impressions': ['B', 'A'], 'value': 3402},
#  {'identifier': 25, 'impressions': ['C', 'B', 'A'], 'value': 4659},
#  {'identifier': 26, 'impressions': ['C', 'B'], 'value': 2325},
#  {'identifier': 27, 'impressions': ['B'], 'value': 1985},
#  {'identifier': 28, 'impressions': ['A'], 'value': 1107},
#  {'identifier': 29, 'impressions': ['C', 'A'], 'value': 316},
#  {'identifier': 30, 'impressions': ['C', 'A'], 'value': 631},
#  {'identifier': 31, 'impressions': ['C', 'A'], 'value': 529},
#  {'identifier': 32, 'impressions': ['C'], 'value': 463},
#  {'identifier': 33, 'impressions': ['B', 'A'], 'value': 318},
#  {'identifier': 34, 'impressions': ['A'], 'value': 108},
#  {'identifier': 35, 'impressions': ['A'], 'value': 3136},
#  {'identifier': 36, 'impressions': ['B', 'A'], 'value': 3941},
#  {'identifier': 37, 'impressions': ['B'], 'value': 1557},
#  {'identifier': 38, 'impressions': ['C', 'B', 'A'], 'value': 3849},
#  {'identifier': 39, 'impressions': ['C', 'B', 'A'], 'value': 3947},
#  {'identifier': 40, 'impressions': ['C', 'B', 'A'], 'value': 3566},
#  {'identifier': 41, 'impressions': ['C', 'B', 'A'], 'value': 3757},
#  {'identifier': 42, 'impressions': ['C', 'B', 'A'], 'value': 2640},
#  {'identifier': 43, 'impressions': ['C', 'B', 'A'], 'value': 2485},
#  {'identifier': 44, 'impressions': ['C', 'B'], 'value': 1551},
#  {'identifier': 45, 'impressions': ['B'], 'value': 1422},
#  {'identifier': 46, 'impressions': ['B', 'A'], 'value': 2182},
#  {'identifier': 47, 'impressions': ['B', 'A'], 'value': 2272},
#  {'identifier': 48, 'impressions': ['B', 'A'], 'value': 1898},
#  {'identifier': 49, 'impressions': ['B', 'A'], 'value': 2946},
#  {'identifier': 50, 'impressions': ['B'], 'value': 1299},
#  {'identifier': 51, 'impressions': ['B', 'A'], 'value': 1835},
#  {'identifier': 52, 'impressions': ['B', 'A'], 'value': 1063},
#  {'identifier': 53, 'impressions': ['B', 'A'], 'value': 1229},
#  {'identifier': 54, 'impressions': ['B', 'A'], 'value': 1102},
#  {'identifier': 55, 'impressions': ['B', 'A'], 'value': 2281},
#  {'identifier': 56, 'impressions': ['B'], 'value': 1051},
#  {'identifier': 57, 'impressions': ['A'], 'value': 965},
#  {'identifier': 58, 'impressions': ['A'], 'value': 2023},
#  {'identifier': 59, 'impressions': ['A'], 'value': 197},
#  {'identifier': 60, 'impressions': ['B', 'A'], 'value': 1396},
#  {'identifier': 61, 'impressions': ['B', 'A'], 'value': 1974},
#  {'identifier': 62, 'impressions': ['B', 'A'], 'value': 3856},
#  {'identifier': 63, 'impressions': ['B', 'A'], 'value': 1308},
#  {'identifier': 64, 'impressions': ['A'], 'value': 1394},
#  {'identifier': 65, 'impressions': ['C', 'A'], 'value': 770},
#  {'identifier': 66, 'impressions': ['C', 'A'], 'value': 554},
#  {'identifier': 67, 'impressions': ['A'], 'value': 422},
#  {'identifier': 68, 'impressions': ['B', 'A'], 'value': 184},
#  {'identifier': 69, 'impressions': ['B', 'A'], 'value': 156},
#  {'identifier': 70, 'impressions': ['B', 'A'], 'value': 80},
#  {'identifier': 71, 'impressions': ['B'], 'value': 39},
#  {'identifier': 72, 'impressions': ['B'], 'value': 1011},
#  {'identifier': 73, 'impressions': ['B', 'A'], 'value': 433},
#  {'identifier': 74, 'impressions': ['B', 'A'], 'value': 351},
#  {'identifier': 75, 'impressions': ['A'], 'value': 1809},
#  {'identifier': 76, 'impressions': ['B', 'A'], 'value': 1199},
#  {'identifier': 77, 'impressions': ['B', 'A'], 'value': 1417},
#  {'identifier': 78, 'impressions': ['B'], 'value': 1434},
#  {'identifier': 79, 'impressions': ['A'], 'value': 341},
#  {'identifier': 80, 'impressions': ['A'], 'value': 907},
#  {'identifier': 81, 'impressions': ['B'], 'value': 120},
#  {'identifier': 82, 'impressions': ['A'], 'value': 2415},
#  {'identifier': 83, 'impressions': ['B'], 'value': 414},
#  {'identifier': 84, 'impressions': ['C', 'B', 'A'], 'value': 2185},
#  {'identifier': 85, 'impressions': ['C', 'B', 'A'], 'value': 2260},
#  {'identifier': 86, 'impressions': ['B', 'A'], 'value': 2291},
#  {'identifier': 87, 'impressions': ['C', 'B', 'A'], 'value': 2578},
#  {'identifier': 88, 'impressions': ['C', 'B', 'A'], 'value': 3234},
#  {'identifier': 89, 'impressions': ['C', 'B', 'A'], 'value': 3417},
#  {'identifier': 90, 'impressions': ['C', 'B', 'A'], 'value': 3706},
#  {'identifier': 91, 'impressions': ['B', 'A'], 'value': 2948},
#  {'identifier': 92, 'impressions': ['B', 'A'], 'value': 3114},
#  {'identifier': 93, 'impressions': ['B'], 'value': 2685},
#  {'identifier': 94, 'impressions': ['A'], 'value': 800},
#  {'identifier': 95, 'impressions': ['A'], 'value': 910},
#  {'identifier': 96, 'impressions': ['B', 'A'], 'value': 134},
#  {'identifier': 97, 'impressions': ['B', 'A'], 'value': 125},
#  {'identifier': 98, 'impressions': ['B'], 'value': 79},
#  {'identifier': 99, 'impressions': ['B', 'A'], 'value': 46},
#  {'identifier': 100, 'impressions': ['B'], 'value': 46},
#  {'identifier': 101, 'impressions': ['A'], 'value': 33},
#  {'identifier': 102, 'impressions': ['B', 'A'], 'value': 2482},
#  {'identifier': 103, 'impressions': ['B', 'A'], 'value': 2193},
#  {'identifier': 104, 'impressions': ['C', 'B', 'A'], 'value': 2496},
#  {'identifier': 105, 'impressions': ['C', 'B', 'A'], 'value': 2669},
#  {'identifier': 106, 'impressions': ['C', 'B', 'A'], 'value': 2479},
#  {'identifier': 107, 'impressions': ['C', 'B'], 'value': 1838},
#  {'identifier': 108, 'impressions': ['B'], 'value': 1590},
#  {'identifier': 109, 'impressions': ['A'], 'value': 1184},
#  {'identifier': 110, 'impressions': ['B', 'A'], 'value': 248},
#  {'identifier': 111, 'impressions': ['B'], 'value': 248},
#  {'identifier': 112, 'impressions': ['B', 'A'], 'value': 1935},
#  {'identifier': 113, 'impressions': ['B', 'A'], 'value': 2350},
#  {'identifier': 114, 'impressions': ['B'], 'value': 710},
#  {'identifier': 115, 'impressions': ['A'], 'value': 2034},
#  {'identifier': 116, 'impressions': ['B', 'A'], 'value': 1525},
#  {'identifier': 117, 'impressions': ['B', 'A'], 'value': 1124},
#  {'identifier': 118, 'impressions': ['B', 'A'], 'value': 1384},
#  {'identifier': 119, 'impressions': ['B', 'A'], 'value': 1111},
#  {'identifier': 120, 'impressions': ['B', 'A'], 'value': 1202},
#  {'identifier': 121, 'impressions': ['B'], 'value': 887},
#  {'identifier': 122, 'impressions': ['B', 'A'], 'value': 167},
#  {'identifier': 123, 'impressions': ['B', 'A'], 'value': 129},
#  {'identifier': 124, 'impressions': ['A'], 'value': 317},
#  {'identifier': 125, 'impressions': ['A'], 'value': 1580},
#  {'identifier': 126, 'impressions': ['B'], 'value': 815},
#  {'identifier': 127, 'impressions': ['B', 'A'], 'value': 140},
#  {'identifier': 128, 'impressions': ['A'], 'value': 1242},
#  {'identifier': 129, 'impressions': ['B', 'A'], 'value': 2467},
#  {'identifier': 130, 'impressions': ['B', 'A'], 'value': 2733},
#  {'identifier': 131, 'impressions': ['B', 'A'], 'value': 4725},
#  {'identifier': 132, 'impressions': ['B', 'A'], 'value': 1831},
#  {'identifier': 133, 'impressions': ['B'], 'value': 1240},
#  {'identifier': 134, 'impressions': ['B', 'A'], 'value': 2397},
#  {'identifier': 135, 'impressions': ['B'], 'value': 1154},
#  {'identifier': 136, 'impressions': ['B', 'A'], 'value': 541},
#  {'identifier': 137, 'impressions': ['B', 'A'], 'value': 566},
#  {'identifier': 138, 'impressions': ['B', 'A'], 'value': 321},
#  {'identifier': 139, 'impressions': ['A'], 'value': 664},
#  {'identifier': 140, 'impressions': ['B', 'A'], 'value': 1883},
#  {'identifier': 141, 'impressions': ['B', 'A'], 'value': 1822},
#  {'identifier': 142, 'impressions': ['B', 'A'], 'value': 2668},
#  {'identifier': 143, 'impressions': ['B', 'A'], 'value': 3262},
#  {'identifier': 144, 'impressions': ['B', 'A'], 'value': 3154},
#  {'identifier': 145, 'impressions': ['B'], 'value': 2406},
#  {'identifier': 146, 'impressions': ['B', 'A'], 'value': 2114},
#  {'identifier': 147, 'impressions': ['B', 'A'], 'value': 1094},
#  {'identifier': 148, 'impressions': ['C', 'B', 'A'], 'value': 1464},
#  {'identifier': 149, 'impressions': ['C', 'B', 'A'], 'value': 1276},
#  {'identifier': 150, 'impressions': ['C', 'B', 'A'], 'value': 1056},
#  {'identifier': 151, 'impressions': ['B', 'A'], 'value': 745},
#  {'identifier': 152, 'impressions': ['B', 'A'], 'value': 751},
#  {'identifier': 153, 'impressions': ['B'], 'value': 575},
#  {'identifier': 154, 'impressions': ['B', 'A'], 'value': 991},
#  {'identifier': 155, 'impressions': ['C', 'B', 'A'], 'value': 1330},
#  {'identifier': 156, 'impressions': ['C', 'B', 'A'], 'value': 1196},
#  {'identifier': 157, 'impressions': ['C', 'B', 'A'], 'value': 1240},
#  {'identifier': 158, 'impressions': ['C', 'B', 'A'], 'value': 1581},
#  {'identifier': 159, 'impressions': ['B', 'A'], 'value': 1241},
#  {'identifier': 160, 'impressions': ['A'], 'value': 1265},
#  {'identifier': 161, 'impressions': ['A'], 'value': 686},
#  {'identifier': 162, 'impressions': ['C', 'B', 'A'], 'value': 1584},
#  {'identifier': 163, 'impressions': ['B', 'A'], 'value': 1604},
#  {'identifier': 164, 'impressions': ['C', 'B', 'A'], 'value': 1575},
#  {'identifier': 165, 'impressions': ['C', 'B', 'A'], 'value': 1077},
#  {'identifier': 166, 'impressions': ['C', 'B', 'A'], 'value': 857},
#  {'identifier': 167, 'impressions': ['C', 'B'], 'value': 347},
#  {'identifier': 168, 'impressions': ['B'], 'value': 139},
#  {'identifier': 169, 'impressions': ['B', 'A'], 'value': 927},
#  {'identifier': 170, 'impressions': ['B', 'A'], 'value': 465},
#  {'identifier': 171, 'impressions': ['A'], 'value': 236},
#  {'identifier': 172, 'impressions': ['B', 'A'], 'value': 469},
#  {'identifier': 173, 'impressions': ['B', 'A'], 'value': 564},
#  {'identifier': 174, 'impressions': ['B', 'A'], 'value': 187},
#  {'identifier': 175, 'impressions': ['A'], 'value': 132},
#  {'identifier': 176, 'impressions': ['B'], 'value': 760},
#  {'identifier': 177, 'impressions': ['A'], 'value': 1676},
#  {'identifier': 178, 'impressions': ['B', 'A'], 'value': 449},
#  {'identifier': 179, 'impressions': ['B', 'A'], 'value': 1155},
#  {'identifier': 180, 'impressions': ['B', 'A'], 'value': 682},
#  {'identifier': 181, 'impressions': ['A'], 'value': 695},
#  {'identifier': 182, 'impressions': ['A'], 'value': 906},
#  {'identifier': 183, 'impressions': ['B', 'A'], 'value': 1021},
#  {'identifier': 184, 'impressions': ['B'], 'value': 762},
#  {'identifier': 185, 'impressions': ['B', 'A'], 'value': 656},
#  {'identifier': 186, 'impressions': ['C', 'A'], 'value': 751},
#  {'identifier': 187, 'impressions': ['C'], 'value': 306},
#  {'identifier': 188, 'impressions': ['B'], 'value': 202},
#  {'identifier': 189, 'impressions': ['C', 'B', 'A'], 'value': 2548},
#  {'identifier': 190, 'impressions': ['C', 'B', 'A'], 'value': 572},
#  {'identifier': 191, 'impressions': ['C', 'A'], 'value': 678},
#  {'identifier': 192, 'impressions': ['C'], 'value': 641},
#  {'identifier': 193, 'impressions': ['A'], 'value': 1320},
#  {'identifier': 194, 'impressions': ['A'], 'value': 527},
#  {'identifier': 195, 'impressions': ['C', 'B', 'A'], 'value': 2472},
#  {'identifier': 196, 'impressions': ['C', 'B', 'A'], 'value': 2487},
#  {'identifier': 197, 'impressions': ['C', 'B', 'A'], 'value': 2779},
#  {'identifier': 198, 'impressions': ['C', 'B', 'A'], 'value': 2439},
#  {'identifier': 199, 'impressions': ['C', 'B', 'A'], 'value': 2280},
#  {'identifier': 200, 'impressions': ['C', 'B'], 'value': 2693},
#  {'identifier': 201, 'impressions': ['C', 'B'], 'value': 2201},
#  {'identifier': 202, 'impressions': ['C', 'B'], 'value': 1586},
#  {'identifier': 203, 'impressions': ['B'], 'value': 1411},
#  {'identifier': 204, 'impressions': ['A'], 'value': 1434},
#  {'identifier': 205, 'impressions': ['A'], 'value': 230},
#  {'identifier': 206, 'impressions': ['B', 'A'], 'value': 943},
#  {'identifier': 207, 'impressions': ['B', 'A'], 'value': 1087},
#  {'identifier': 208, 'impressions': ['B', 'A'], 'value': 975},
#  {'identifier': 209, 'impressions': ['B', 'A'], 'value': 1142},
#  {'identifier': 210, 'impressions': ['C', 'B', 'A'], 'value': 822},
#  {'identifier': 211, 'impressions': ['C', 'B', 'A'], 'value': 710},
#  {'identifier': 212, 'impressions': ['C', 'B', 'A'], 'value': 228},
#  {'identifier': 213, 'impressions': ['C', 'B', 'A'], 'value': 145},
#  {'identifier': 214, 'impressions': ['B', 'A'], 'value': 0},
#  {'identifier': 215, 'impressions': ['A'], 'value': 0},
#  {'identifier': 216, 'impressions': ['C', 'A'], 'value': 2425},
#  {'identifier': 217, 'impressions': ['C', 'A'], 'value': 1692},
#  {'identifier': 218, 'impressions': ['C', 'A'], 'value': 1500},
#  {'identifier': 219, 'impressions': ['C'], 'value': 1215},
#  {'identifier': 220, 'impressions': ['A'], 'value': 470},
#  {'identifier': 221, 'impressions': ['B', 'A'], 'value': 1053},
#  {'identifier': 222, 'impressions': ['B', 'A'], 'value': 2197},
#  {'identifier': 223, 'impressions': ['B'], 'value': 723},
#  {'identifier': 224, 'impressions': ['C', 'A'], 'value': 320},
#  {'identifier': 225, 'impressions': ['A'], 'value': 326},
#  {'identifier': 226, 'impressions': ['B', 'A'], 'value': 2715},
#  {'identifier': 227, 'impressions': ['B'], 'value': 308},
#  {'identifier': 228, 'impressions': ['B', 'A'], 'value': 1531},
#  {'identifier': 229, 'impressions': ['B', 'A'], 'value': 1654},
#  {'identifier': 230, 'impressions': ['B', 'A'], 'value': 2838},
#  {'identifier': 231, 'impressions': ['B'], 'value': 557},
#  {'identifier': 232, 'impressions': ['A'], 'value': 80},
#  {'identifier': 233, 'impressions': ['C', 'B', 'A'], 'value': 2027},
#  {'identifier': 234, 'impressions': ['C', 'B', 'A'], 'value': 1887},
#  {'identifier': 235, 'impressions': ['C', 'B', 'A'], 'value': 2720},
#  {'identifier': 236, 'impressions': ['C', 'B', 'A'], 'value': 3129},
#  {'identifier': 237, 'impressions': ['C', 'A'], 'value': 3096},
#  {'identifier': 238, 'impressions': ['C'], 'value': 2419},
#  {'identifier': 239, 'impressions': ['B', 'A'], 'value': 1154},
#  {'identifier': 240, 'impressions': ['B', 'A'], 'value': 1345},
#  {'identifier': 241, 'impressions': ['B', 'A'], 'value': 999},
#  {'identifier': 242, 'impressions': ['B', 'A'], 'value': 897},
#  {'identifier': 243, 'impressions': ['B', 'A'], 'value': 528},
#  {'identifier': 244, 'impressions': ['B', 'A'], 'value': 504},
#  {'identifier': 245, 'impressions': ['A'], 'value': 1159},
#  {'identifier': 246, 'impressions': ['B', 'A'], 'value': 287},
#  {'identifier': 247, 'impressions': ['B', 'A'], 'value': 105},
#  {'identifier': 248, 'impressions': ['B', 'A'], 'value': 302},
#  {'identifier': 249, 'impressions': ['A'], 'value': 361},
#  {'identifier': 250, 'impressions': ['B', 'A'], 'value': 1037},
#  {'identifier': 251, 'impressions': ['B', 'A'], 'value': 910},
#  {'identifier': 252, 'impressions': ['A'], 'value': 1232},
#  {'identifier': 253, 'impressions': ['B', 'A'], 'value': 1347},
#  {'identifier': 254, 'impressions': ['B'], 'value': 394},
#  {'identifier': 255, 'impressions': ['A'], 'value': 127},
#  {'identifier': 256, 'impressions': ['A'], 'value': 261},
#  {'identifier': 257, 'impressions': ['C', 'B', 'A'], 'value': 3144},
#  {'identifier': 258, 'impressions': ['C', 'B', 'A'], 'value': 2959},
#  {'identifier': 259, 'impressions': ['B', 'A'], 'value': 2783},
#  {'identifier': 260, 'impressions': ['B', 'A'], 'value': 3143},
#  {'identifier': 261, 'impressions': ['B', 'A'], 'value': 3178},
#  {'identifier': 262, 'impressions': ['C', 'B', 'A'], 'value': 3159},
#  {'identifier': 263, 'impressions': ['C', 'B', 'A'], 'value': 3230},
#  {'identifier': 264, 'impressions': ['C', 'B', 'A'], 'value': 3426},
#  {'identifier': 265, 'impressions': ['C', 'B'], 'value': 2597},
#  {'identifier': 266, 'impressions': ['B'], 'value': 2413},
#  {'identifier': 267, 'impressions': ['A'], 'value': 434},
#  {'identifier': 268, 'impressions': ['A'], 'value': 1548},
#  {'identifier': 269, 'impressions': ['B', 'A'], 'value': 3310},
#  {'identifier': 270, 'impressions': ['C', 'B', 'A'], 'value': 2984},
#  {'identifier': 271, 'impressions': ['C', 'B', 'A'], 'value': 3420},
#  {'identifier': 272, 'impressions': ['C', 'B', 'A'], 'value': 3405},
#  {'identifier': 273, 'impressions': ['C', 'B', 'A'], 'value': 3966},
#  {'identifier': 274, 'impressions': ['C', 'B', 'A'], 'value': 3213},
#  {'identifier': 275, 'impressions': ['C', 'B', 'A'], 'value': 3140},
#  {'identifier': 276, 'impressions': ['C', 'B'], 'value': 2746},
#  {'identifier': 277, 'impressions': ['C'], 'value': 2404},
#  {'identifier': 278, 'impressions': ['B', 'A'], 'value': 185},
#  {'identifier': 279, 'impressions': ['A'], 'value': 167},
#  {'identifier': 280, 'impressions': ['A'], 'value': 509},
#  {'identifier': 281, 'impressions': ['C', 'B', 'A'], 'value': 795},
#  {'identifier': 282, 'impressions': ['C', 'B', 'A'], 'value': 492},
#  {'identifier': 283, 'impressions': ['B', 'A'], 'value': 367},
#  {'identifier': 284, 'impressions': ['B', 'A'], 'value': 354},
#  {'identifier': 285, 'impressions': ['B'], 'value': 224},
#  {'identifier': 286, 'impressions': ['B', 'A'], 'value': 842},
#  {'identifier': 287, 'impressions': ['B', 'A'], 'value': 1636},
#  {'identifier': 288, 'impressions': ['B', 'A'], 'value': 1001},
#  {'identifier': 289, 'impressions': ['A'], 'value': 983},
#  {'identifier': 290, 'impressions': ['A'], 'value': 594},
#  {'identifier': 291, 'impressions': ['A'], 'value': 779},
#  {'identifier': 292, 'impressions': ['A'], 'value': 865},
#  {'identifier': 293, 'impressions': ['A'], 'value': 670},
#  {'identifier': 294, 'impressions': ['A'], 'value': 1119},
#  {'identifier': 295, 'impressions': ['B', 'A'], 'value': 3982},
#  {'identifier': 296, 'impressions': ['B', 'A'], 'value': 1961},
#  {'identifier': 297, 'impressions': ['C', 'B', 'A'], 'value': 3553},
#  {'identifier': 298, 'impressions': ['C', 'B', 'A'], 'value': 2535},
#  {'identifier': 299, 'impressions': ['C', 'B', 'A'], 'value': 1965},
#  {'identifier': 300, 'impressions': ['C', 'B'], 'value': 1547},
#  {'identifier': 301, 'impressions': ['B'], 'value': 1322},
#  {'identifier': 302, 'impressions': ['C', 'A'], 'value': 1709},
#  {'identifier': 303, 'impressions': ['C', 'A'], 'value': 1657},
#  {'identifier': 304, 'impressions': ['C', 'A'], 'value': 1356},
#  {'identifier': 305, 'impressions': ['C'], 'value': 869},
#  {'identifier': 306, 'impressions': ['B', 'A'], 'value': 2481},
#  {'identifier': 307, 'impressions': ['B', 'A'], 'value': 858},
#  {'identifier': 308, 'impressions': ['B', 'A'], 'value': 1361},
#  {'identifier': 309, 'impressions': ['B'], 'value': 849},
#  {'identifier': 310, 'impressions': ['B', 'A'], 'value': 1047},
#  {'identifier': 311, 'impressions': ['B', 'A'], 'value': 983},
#  {'identifier': 312, 'impressions': ['B', 'A'], 'value': 354},
#  {'identifier': 313, 'impressions': ['A'], 'value': 657},
#  {'identifier': 314, 'impressions': ['B', 'A'], 'value': 836},
#  {'identifier': 315, 'impressions': ['B', 'A'], 'value': 730},
#  {'identifier': 316, 'impressions': ['A'], 'value': 1315},
#  {'identifier': 317, 'impressions': ['B', 'A'], 'value': 3970},
#  {'identifier': 318, 'impressions': ['B'], 'value': 648},
#  {'identifier': 319, 'impressions': ['A'], 'value': 834},
#  {'identifier': 320, 'impressions': ['B', 'A'], 'value': 257},
#  {'identifier': 321, 'impressions': ['B'], 'value': 102},
#  {'identifier': 322, 'impressions': ['A'], 'value': 57},
#  {'identifier': 323, 'impressions': ['B'], 'value': 669},
#  {'identifier': 324, 'impressions': ['B'], 'value': 574},
#  {'identifier': 325, 'impressions': ['A'], 'value': 1359},
#  {'identifier': 326, 'impressions': ['A'], 'value': 547},
#  {'identifier': 327, 'impressions': ['A'], 'value': 127},
#  {'identifier': 328, 'impressions': ['B', 'A'], 'value': 945},
#  {'identifier': 329, 'impressions': ['B', 'A'], 'value': 299},
#  {'identifier': 330, 'impressions': ['B', 'A'], 'value': 281},
#  {'identifier': 331, 'impressions': ['B', 'A'], 'value': 386},
#  {'identifier': 332, 'impressions': ['A'], 'value': 425},
#  {'identifier': 333, 'impressions': ['C', 'B', 'A'], 'value': 1578},
#  {'identifier': 334, 'impressions': ['C', 'B', 'A'], 'value': 656},
#  {'identifier': 335, 'impressions': ['C', 'B', 'A'], 'value': 473},
#  {'identifier': 336, 'impressions': ['C', 'B', 'A'], 'value': 273},
#  {'identifier': 337, 'impressions': ['B', 'A'], 'value': 238},
#  {'identifier': 338, 'impressions': ['B'], 'value': 220},
#  {'identifier': 339, 'impressions': ['B', 'A'], 'value': 299},
#  {'identifier': 340, 'impressions': ['B', 'A'], 'value': 139},
#  {'identifier': 341, 'impressions': ['A'], 'value': 150},
#  {'identifier': 342, 'impressions': ['B'], 'value': 272},
#  {'identifier': 343, 'impressions': ['B', 'A'], 'value': 8245},
#  {'identifier': 344, 'impressions': ['B'], 'value': 815},
#  {'identifier': 345, 'impressions': ['A'], 'value': 13},
#  {'identifier': 346, 'impressions': ['A'], 'value': 683},
#  {'identifier': 347, 'impressions': ['C', 'B', 'A'], 'value': 865},
#  {'identifier': 348, 'impressions': ['C', 'B', 'A'], 'value': 660},
#  {'identifier': 349, 'impressions': ['C', 'B', 'A'], 'value': 654},
#  {'identifier': 350, 'impressions': ['C', 'B', 'A'], 'value': 716},
#  {'identifier': 351, 'impressions': ['B', 'A'], 'value': 566},
#  {'identifier': 352, 'impressions': ['B', 'A'], 'value': 629},
#  {'identifier': 353, 'impressions': ['B'], 'value': 594},
#  {'identifier': 354, 'impressions': ['C', 'B', 'A'], 'value': 327},
#  {'identifier': 355, 'impressions': ['B', 'A'], 'value': 358},
#  {'identifier': 356, 'impressions': ['B', 'A'], 'value': 579},
#  {'identifier': 357, 'impressions': ['A'], 'value': 824},
#  {'identifier': 358, 'impressions': ['B', 'A'], 'value': 605},
#  {'identifier': 359, 'impressions': ['B', 'A'], 'value': 519},
#  {'identifier': 360, 'impressions': ['A'], 'value': 566},
#  {'identifier': 361, 'impressions': ['B'], 'value': 216},
#  {'identifier': 362, 'impressions': ['B', 'A'], 'value': 3762},
#  {'identifier': 363, 'impressions': ['B'], 'value': 1256},
#  {'identifier': 364, 'impressions': ['A'], 'value': 587},
#  {'identifier': 365, 'impressions': ['B', 'A'], 'value': 592},
#  {'identifier': 366, 'impressions': ['A'], 'value': 1080},
#  {'identifier': 367, 'impressions': ['B', 'A'], 'value': 1238},
#  {'identifier': 368, 'impressions': ['B', 'A'], 'value': 1106},
#  {'identifier': 369, 'impressions': ['B', 'A'], 'value': 1100},
#  {'identifier': 370, 'impressions': ['B'], 'value': 513},
#  {'identifier': 371, 'impressions': ['B', 'A'], 'value': 426},
#  {'identifier': 372, 'impressions': ['B', 'A'], 'value': 561},
#  {'identifier': 373, 'impressions': ['B', 'A'], 'value': 649},
#  {'identifier': 374, 'impressions': ['B', 'A'], 'value': 636},
#  {'identifier': 375, 'impressions': ['A'], 'value': 1373},
#  {'identifier': 376, 'impressions': ['A'], 'value': 1469},
#  {'identifier': 377, 'impressions': ['A'], 'value': 107},
#  {'identifier': 378, 'impressions': ['A'], 'value': 386},
#  {'identifier': 379, 'impressions': ['B', 'A'], 'value': 134},
#  {'identifier': 380, 'impressions': ['A'], 'value': 348},
#  {'identifier': 381, 'impressions': ['A'], 'value': 200},
#  {'identifier': 382, 'impressions': ['B', 'A'], 'value': 447},
#  {'identifier': 383, 'impressions': ['B'], 'value': 50},
#  {'identifier': 384, 'impressions': ['B', 'A'], 'value': 2084},
#  {'identifier': 385, 'impressions': ['B', 'A'], 'value': 1840},
#  {'identifier': 386, 'impressions': ['B', 'A'], 'value': 1304},
#  {'identifier': 387, 'impressions': ['A'], 'value': 1694},
#  {'identifier': 388, 'impressions': ['A'], 'value': 414},
#  {'identifier': 389, 'impressions': ['A'], 'value': 148},
#  {'identifier': 390, 'impressions': ['A'], 'value': 7},
#  {'identifier': 391, 'impressions': ['A'], 'value': 813},
#  {'identifier': 392, 'impressions': ['A'], 'value': 692},
#  {'identifier': 393, 'impressions': ['B', 'A'], 'value': 634},
#  {'identifier': 394, 'impressions': ['B'], 'value': 499},
#  {'identifier': 395, 'impressions': ['B', 'A'], 'value': 2496},
#  {'identifier': 396, 'impressions': ['B', 'A'], 'value': 618},
#  {'identifier': 397, 'impressions': ['A'], 'value': 608},
#  {'identifier': 398, 'impressions': ['A'], 'value': 401},
#  {'identifier': 399, 'impressions': ['A'], 'value': 887},
#  {'identifier': 400, 'impressions': ['B', 'A'], 'value': 1176},
#  {'identifier': 401, 'impressions': ['B', 'A'], 'value': 1312},
#  {'identifier': 402, 'impressions': ['B', 'A'], 'value': 1224},
#  {'identifier': 403, 'impressions': ['B', 'A'], 'value': 889},
#  {'identifier': 404, 'impressions': ['B', 'A'], 'value': 823},
#  {'identifier': 405, 'impressions': ['B'], 'value': 294},
#  {'identifier': 406, 'impressions': ['C', 'B', 'A'], 'value': 1343},
#  {'identifier': 407, 'impressions': ['C', 'B', 'A'], 'value': 1274},
#  {'identifier': 408, 'impressions': ['C', 'B', 'A'], 'value': 1386},
#  {'identifier': 409, 'impressions': ['C', 'B', 'A'], 'value': 1478},
#  {'identifier': 410, 'impressions': ['C', 'B', 'A'], 'value': 1211},
#  {'identifier': 411, 'impressions': ['C', 'B'], 'value': 1030},
#  {'identifier': 412, 'impressions': ['C', 'B'], 'value': 965},
#  {'identifier': 413, 'impressions': ['B'], 'value': 954},
#  {'identifier': 414, 'impressions': ['B'], 'value': 541},
#  {'identifier': 415, 'impressions': ['B', 'A'], 'value': 1495},
#  {'identifier': 416, 'impressions': ['B', 'A'], 'value': 1182},
#  {'identifier': 417, 'impressions': ['B', 'A'], 'value': 1351},
#  {'identifier': 418, 'impressions': ['B'], 'value': 1351},
#  {'identifier': 419, 'impressions': ['B', 'A'], 'value': 469},
#  {'identifier': 420, 'impressions': ['B', 'A'], 'value': 734},
#  {'identifier': 421, 'impressions': ['B', 'A'], 'value': 2175},
#  {'identifier': 422, 'impressions': ['B', 'A'], 'value': 869},
#  {'identifier': 423, 'impressions': ['B', 'A'], 'value': 853},
#  {'identifier': 424, 'impressions': ['B'], 'value': 629},
#  {'identifier': 425, 'impressions': ['B', 'A'], 'value': 2066},
#  {'identifier': 426, 'impressions': ['B', 'A'], 'value': 1302},
#  {'identifier': 427, 'impressions': ['B', 'A'], 'value': 2553},
#  {'identifier': 428, 'impressions': ['B'], 'value': 1259},
#  {'identifier': 429, 'impressions': ['C', 'A'], 'value': 2053},
#  {'identifier': 430, 'impressions': ['C', 'A'], 'value': 1152},
#  {'identifier': 431, 'impressions': ['C', 'A'], 'value': 931},
#  {'identifier': 432, 'impressions': ['C'], 'value': 717},
#  {'identifier': 433, 'impressions': ['A'], 'value': 646},
#  {'identifier': 434, 'impressions': ['C', 'A'], 'value': 1378},
#  {'identifier': 435, 'impressions': ['C', 'A'], 'value': 597},
#  {'identifier': 436, 'impressions': ['A'], 'value': 347},
#  {'identifier': 437, 'impressions': ['B', 'A'], 'value': 552},
#  {'identifier': 438, 'impressions': ['A'], 'value': 1429},
#  {'identifier': 439, 'impressions': ['A'], 'value': 555},
#  {'identifier': 440, 'impressions': ['A'], 'value': 1476},
#  {'identifier': 441, 'impressions': ['A'], 'value': 642},
#  {'identifier': 442, 'impressions': ['B'], 'value': 441},
#  {'identifier': 443, 'impressions': ['B', 'A'], 'value': 3225},
#  {'identifier': 444, 'impressions': ['B', 'A'], 'value': 1678},
#  {'identifier': 445, 'impressions': ['A'], 'value': 1736},
#  {'identifier': 446, 'impressions': ['B', 'A'], 'value': 6198},
#  {'identifier': 447, 'impressions': ['B', 'A'], 'value': 2326},
#  {'identifier': 448, 'impressions': ['B', 'A'], 'value': 4227},
#  {'identifier': 449, 'impressions': ['B'], 'value': 1591},
#  {'identifier': 450, 'impressions': ['B', 'A'], 'value': 567},
#  {'identifier': 451, 'impressions': ['A'], 'value': 536},
#  {'identifier': 452, 'impressions': ['A'], 'value': 1496},
#  {'identifier': 453, 'impressions': ['A'], 'value': 1610},
#  {'identifier': 454, 'impressions': ['C', 'A'], 'value': 653},
#  {'identifier': 455, 'impressions': ['C'], 'value': 442},
#  {'identifier': 456, 'impressions': ['A'], 'value': 0},
#  {'identifier': 457, 'impressions': ['A'], 'value': 319},
#  {'identifier': 458, 'impressions': ['A'], 'value': 570},
#  {'identifier': 459, 'impressions': ['B', 'A'], 'value': 1961},
#  {'identifier': 460, 'impressions': ['B'], 'value': 317},
#  {'identifier': 461, 'impressions': ['B', 'A'], 'value': 1934},
#  {'identifier': 462, 'impressions': ['B', 'A'], 'value': 2045},
#  {'identifier': 463, 'impressions': ['B', 'A'], 'value': 1968},
#  {'identifier': 464, 'impressions': ['B', 'A'], 'value': 1080},
#  {'identifier': 465, 'impressions': ['B', 'A'], 'value': 692},
#  {'identifier': 466, 'impressions': ['B'], 'value': 64},
#  {'identifier': 467, 'impressions': ['C', 'B', 'A'], 'value': 4585},
#  {'identifier': 468, 'impressions': ['C', 'B', 'A'], 'value': 1650},
#  {'identifier': 469, 'impressions': ['C', 'A'], 'value': 2373},
#  {'identifier': 470, 'impressions': ['C', 'A'], 'value': 2620},
#  {'identifier': 471, 'impressions': ['A'], 'value': 1803},
#  {'identifier': 472, 'impressions': ['B', 'A'], 'value': 254},
#  {'identifier': 473, 'impressions': ['B'], 'value': 134},
#  {'identifier': 474, 'impressions': ['B', 'A'], 'value': 1444},
#  {'identifier': 475, 'impressions': ['B', 'A'], 'value': 697},
#  {'identifier': 476, 'impressions': ['C', 'B', 'A'], 'value': 1588},
#  {'identifier': 477, 'impressions': ['C', 'B', 'A'], 'value': 1427},
#  {'identifier': 478, 'impressions': ['C', 'B', 'A'], 'value': 1205},
#  {'identifier': 479, 'impressions': ['C', 'B'], 'value': 1027},
#  {'identifier': 480, 'impressions': ['B'], 'value': 906},
#  {'identifier': 481, 'impressions': ['B', 'A'], 'value': 2604},
#  {'identifier': 482, 'impressions': ['B'], 'value': 1116},
#  {'identifier': 483, 'impressions': ['B', 'A'], 'value': 1859},
#  {'identifier': 484, 'impressions': ['B', 'A'], 'value': 1904},
#  {'identifier': 485, 'impressions': ['B', 'A'], 'value': 1618},
#  {'identifier': 486, 'impressions': ['B', 'A'], 'value': 2888},
#  {'identifier': 487, 'impressions': ['B'], 'value': 1462},
#  {'identifier': 488, 'impressions': ['A'], 'value': 232},
#  {'identifier': 489, 'impressions': ['A'], 'value': 163},
#  {'identifier': 490, 'impressions': ['A'], 'value': 105},
#  {'identifier': 491, 'impressions': ['A'], 'value': 1029},
#  {'identifier': 492, 'impressions': ['B'], 'value': 1107},
#  {'identifier': 493, 'impressions': ['A'], 'value': 1681},
#  {'identifier': 494, 'impressions': ['B'], 'value': 509},
#  {'identifier': 495, 'impressions': ['A'], 'value': 394},
#  {'identifier': 496, 'impressions': ['C', 'B', 'A'], 'value': 1845},
#  {'identifier': 497, 'impressions': ['C', 'B', 'A'], 'value': 2193},
#  {'identifier': 498, 'impressions': ['C', 'A'], 'value': 2527},
#  {'identifier': 499, 'impressions': ['C', 'B', 'A'], 'value': 2653},
#  {'identifier': 500, 'impressions': ['C', 'B', 'A'], 'value': 2018},
#  {'identifier': 501, 'impressions': ['C', 'B'], 'value': 1392},
#  {'identifier': 502, 'impressions': ['B'], 'value': 619},
#  {'identifier': 503, 'impressions': ['B', 'A'], 'value': 3382},
#  {'identifier': 504, 'impressions': ['B', 'A'], 'value': 1777},
#  {'identifier': 505, 'impressions': ['C', 'B', 'A'], 'value': 3355},
#  {'identifier': 506, 'impressions': ['C', 'B', 'A'], 'value': 2222},
#  {'identifier': 507, 'impressions': ['C', 'B', 'A'], 'value': 1722},
#  {'identifier': 508, 'impressions': ['C', 'B', 'A'], 'value': 1710},
#  {'identifier': 509, 'impressions': ['C', 'B'], 'value': 1319},
#  {'identifier': 510, 'impressions': ['B'], 'value': 1107},
#  {'identifier': 511, 'impressions': ['A'], 'value': 550},
#  {'identifier': 512, 'impressions': ['A'], 'value': 1089},
#  {'identifier': 513, 'impressions': ['A'], 'value': 1818},
#  {'identifier': 514, 'impressions': ['A'], 'value': 66},
#  {'identifier': 515, 'impressions': ['C', 'B', 'A'], 'value': 940},
#  {'identifier': 516, 'impressions': ['B', 'A'], 'value': 889},
#  {'identifier': 517, 'impressions': ['C', 'B', 'A'], 'value': 734},
#  {'identifier': 518, 'impressions': ['C', 'B', 'A'], 'value': 242},
#  {'identifier': 519, 'impressions': ['C', 'A'], 'value': 354},
#  {'identifier': 520, 'impressions': ['C'], 'value': 425},
#  {'identifier': 521, 'impressions': ['B', 'A'], 'value': 1377},
#  {'identifier': 522, 'impressions': ['B', 'A'], 'value': 1233},
#  {'identifier': 523, 'impressions': ['B', 'A'], 'value': 1280},
#  {'identifier': 524, 'impressions': ['B', 'A'], 'value': 1086},
#  {'identifier': 525, 'impressions': ['B', 'A'], 'value': 1092},
#  {'identifier': 526, 'impressions': ['B'], 'value': 584},
#  {'identifier': 527, 'impressions': ['A'], 'value': 115},
#  {'identifier': 528, 'impressions': ['C', 'B', 'A'], 'value': 214},
#  {'identifier': 529, 'impressions': ['C', 'A'], 'value': 82},
#  {'identifier': 530, 'impressions': ['C'], 'value': 100},
#  {'identifier': 531, 'impressions': ['B', 'A'], 'value': 378},
#  {'identifier': 532, 'impressions': ['A'], 'value': 581},
#  {'identifier': 533, 'impressions': ['B', 'A'], 'value': 215},
#  {'identifier': 534, 'impressions': ['B', 'A'], 'value': 94},
#  {'identifier': 535, 'impressions': ['A'], 'value': 128},
#  {'identifier': 536, 'impressions': ['A'], 'value': 1116},
#  {'identifier': 537, 'impressions': ['A'], 'value': 3562},
#  {'identifier': 538, 'impressions': ['C', 'B', 'A'], 'value': 1936},
#  {'identifier': 539, 'impressions': ['C', 'B', 'A'], 'value': 1078},
#  {'identifier': 540, 'impressions': ['C', 'B', 'A'], 'value': 773},
#  {'identifier': 541, 'impressions': ['C', 'B'], 'value': 611},
#  {'identifier': 542, 'impressions': ['B'], 'value': 540},
#  {'identifier': 543, 'impressions': ['A'], 'value': 1003},
#  {'identifier': 544, 'impressions': ['A'], 'value': 678},
#  {'identifier': 545, 'impressions': ['A'], 'value': 423},
#  {'identifier': 546, 'impressions': ['C', 'A'], 'value': 869},
#  {'identifier': 547, 'impressions': ['C'], 'value': 267},
#  {'identifier': 548, 'impressions': ['B', 'A'], 'value': 1030},
#  {'identifier': 549, 'impressions': ['B', 'A'], 'value': 979},
#  {'identifier': 550, 'impressions': ['B', 'A'], 'value': 647},
#  {'identifier': 551, 'impressions': ['A'], 'value': 1461},
#  {'identifier': 552, 'impressions': ['B'], 'value': 1101},
#  {'identifier': 553, 'impressions': ['B', 'A'], 'value': 2421},
#  {'identifier': 554, 'impressions': ['B', 'A'], 'value': 2012},
#  {'identifier': 555, 'impressions': ['B'], 'value': 1765},
#  {'identifier': 556, 'impressions': ['B', 'A'], 'value': 746},
#  {'identifier': 557, 'impressions': ['B', 'A'], 'value': 602},
#  {'identifier': 558, 'impressions': ['B', 'A'], 'value': 1774},
#  {'identifier': 559, 'impressions': ['A'], 'value': 939},
#  {'identifier': 560, 'impressions': ['B'], 'value': 288},
#  {'identifier': 561, 'impressions': ['B', 'A'], 'value': 1348},
#  {'identifier': 562, 'impressions': ['B', 'A'], 'value': 612},
#  {'identifier': 563, 'impressions': ['B', 'A'], 'value': 464},
#  {'identifier': 564, 'impressions': ['B', 'A'], 'value': 548},
#  {'identifier': 565, 'impressions': ['A'], 'value': 1244},
#  {'identifier': 566, 'impressions': ['B', 'A'], 'value': 731},
#  {'identifier': 567, 'impressions': ['A'], 'value': 787},
#  {'identifier': 568, 'impressions': ['B', 'A'], 'value': 1260},
#  {'identifier': 569, 'impressions': ['A'], 'value': 3129},
#  {'identifier': 570, 'impressions': ['B', 'A'], 'value': 1946},
#  {'identifier': 571, 'impressions': ['B', 'A'], 'value': 1975},
#  {'identifier': 572, 'impressions': ['B', 'A'], 'value': 1667},
#  {'identifier': 573, 'impressions': ['C', 'A'], 'value': 2083},
#  {'identifier': 574, 'impressions': ['C'], 'value': 1039},
#  {'identifier': 575, 'impressions': ['C', 'B', 'A'], 'value': 731},
#  {'identifier': 576, 'impressions': ['C', 'A'], 'value': 949},
#  {'identifier': 577, 'impressions': ['C', 'A'], 'value': 591},
#  {'identifier': 578, 'impressions': ['C'], 'value': 449},
#  {'identifier': 579, 'impressions': ['B', 'A'], 'value': 1094},
#  {'identifier': 580, 'impressions': ['B', 'A'], 'value': 1877},
#  {'identifier': 581, 'impressions': ['B'], 'value': 553},
#  {'identifier': 582, 'impressions': ['B', 'A'], 'value': 967},
#  {'identifier': 583, 'impressions': ['B', 'A'], 'value': 1431},
#  {'identifier': 584, 'impressions': ['B', 'A'], 'value': 1708},
#  {'identifier': 585, 'impressions': ['B', 'A'], 'value': 1022},
#  {'identifier': 586, 'impressions': ['B', 'A'], 'value': 1379},
#  {'identifier': 587, 'impressions': ['B'], 'value': 675},
#  {'identifier': 588, 'impressions': ['A'], 'value': 1549},
#  {'identifier': 589, 'impressions': ['B', 'A'], 'value': 2161},
#  {'identifier': 590, 'impressions': ['B', 'A'], 'value': 663},
#  {'identifier': 591, 'impressions': ['A'], 'value': 784},
#  {'identifier': 592, 'impressions': ['C', 'B', 'A'], 'value': 2450},
#  {'identifier': 593, 'impressions': ['C', 'B', 'A'], 'value': 1827},
#  {'identifier': 594, 'impressions': ['C', 'B', 'A'], 'value': 1631},
#  {'identifier': 595, 'impressions': ['C', 'B', 'A'], 'value': 1683},
#  {'identifier': 596, 'impressions': ['C', 'B'], 'value': 1260},
#  {'identifier': 597, 'impressions': ['B'], 'value': 840},
#  {'identifier': 598, 'impressions': ['A'], 'value': 369},
#  {'identifier': 599, 'impressions': ['B', 'A'], 'value': 2237},
#  {'identifier': 600, 'impressions': ['B', 'A'], 'value': 1098},
#  {'identifier': 601, 'impressions': ['A'], 'value': 1407},
#  {'identifier': 602, 'impressions': ['C', 'B', 'A'], 'value': 1463},
#  {'identifier': 603, 'impressions': ['B', 'A'], 'value': 1458},
#  {'identifier': 604, 'impressions': ['B', 'A'], 'value': 1817},
#  {'identifier': 605, 'impressions': ['B', 'A'], 'value': 2045},
#  {'identifier': 606, 'impressions': ['B', 'A'], 'value': 2029},
#  {'identifier': 607, 'impressions': ['B', 'A'], 'value': 2910},
#  {'identifier': 608, 'impressions': ['B'], 'value': 1508},
#  {'identifier': 609, 'impressions': ['B', 'A'], 'value': 651},
#  {'identifier': 610, 'impressions': ['B', 'A'], 'value': 824},
#  {'identifier': 611, 'impressions': ['C', 'B', 'A'], 'value': 1637},
#  {'identifier': 612, 'impressions': ['C', 'B'], 'value': 356},
#  {'identifier': 613, 'impressions': ['B'], 'value': 356},
#  {'identifier': 614, 'impressions': ['C', 'A'], 'value': 2424},
#  {'identifier': 615, 'impressions': ['C', 'A'], 'value': 2184},
#  {'identifier': 616, 'impressions': ['A'], 'value': 1998},
#  {'identifier': 617, 'impressions': ['A'], 'value': 559},
#  {'identifier': 618, 'impressions': ['A'], 'value': 1313},
#  {'identifier': 619, 'impressions': ['A'], 'value': 806},
#  {'identifier': 620, 'impressions': ['A'], 'value': 928},
#  {'identifier': 621, 'impressions': ['B'], 'value': 741},
#  {'identifier': 622, 'impressions': ['B', 'A'], 'value': 2225},
#  {'identifier': 623, 'impressions': ['B', 'A'], 'value': 1117},
#  {'identifier': 624, 'impressions': ['B', 'A'], 'value': 1778},
#  {'identifier': 625, 'impressions': ['B'], 'value': 917},
#  {'identifier': 626, 'impressions': ['A'], 'value': 319},
#  {'identifier': 627, 'impressions': ['A'], 'value': 308},
#  {'identifier': 628, 'impressions': ['A'], 'value': 2590},
#  {'identifier': 629, 'impressions': ['B', 'A'], 'value': 1418},
#  {'identifier': 630, 'impressions': ['B', 'A'], 'value': 1281},
#  {'identifier': 631, 'impressions': ['B', 'A'], 'value': 1017},
#  {'identifier': 632, 'impressions': ['B', 'A'], 'value': 1436},
#  {'identifier': 633, 'impressions': ['B'], 'value': 513},
#  {'identifier': 634, 'impressions': ['A'], 'value': 839},
#  {'identifier': 635, 'impressions': ['B', 'A'], 'value': 1911},
#  {'identifier': 636, 'impressions': ['B', 'A'], 'value': 2297},
#  {'identifier': 637, 'impressions': ['B', 'A'], 'value': 3979},
#  {'identifier': 638, 'impressions': ['B'], 'value': 1001},
#  {'identifier': 639, 'impressions': ['B', 'A'], 'value': 3084},
#  {'identifier': 640, 'impressions': ['B', 'A'], 'value': 3850},
#  {'identifier': 641, 'impressions': ['B', 'A'], 'value': 3335},
#  {'identifier': 642, 'impressions': ['B', 'A'], 'value': 3117},
#  {'identifier': 643, 'impressions': ['B'], 'value': 2472},
#  {'identifier': 644, 'impressions': ['B', 'A'], 'value': 572},
#  {'identifier': 645, 'impressions': ['C', 'A'], 'value': 1775},
#  {'identifier': 646, 'impressions': ['C'], 'value': 680},
#  {'identifier': 647, 'impressions': ['A'], 'value': 797},
#  {'identifier': 648, 'impressions': ['A'], 'value': 176},
#  {'identifier': 649, 'impressions': ['B', 'A'], 'value': 386},
#  {'identifier': 650, 'impressions': ['B'], 'value': 285},
#  {'identifier': 651, 'impressions': ['A'], 'value': 523},
#  {'identifier': 652, 'impressions': ['B', 'A'], 'value': 1557},
#  {'identifier': 653, 'impressions': ['B', 'A'], 'value': 1384},
#  {'identifier': 654, 'impressions': ['C', 'B', 'A'], 'value': 2555},
#  {'identifier': 655, 'impressions': ['C', 'B'], 'value': 1309},
#  {'identifier': 656, 'impressions': ['B'], 'value': 658},
#  {'identifier': 657, 'impressions': ['A'], 'value': 63},
#  {'identifier': 658, 'impressions': ['A'], 'value': 1371},
#  {'identifier': 659, 'impressions': ['C', 'A'], 'value': 864},
#  {'identifier': 660, 'impressions': ['C', 'B', 'A'], 'value': 1281},
#  {'identifier': 661, 'impressions': ['C', 'B', 'A'], 'value': 728},
#  {'identifier': 662, 'impressions': ['B', 'A'], 'value': 495},
#  {'identifier': 663, 'impressions': ['B', 'A'], 'value': 579},
#  {'identifier': 664, 'impressions': ['B'], 'value': 415},
#  {'identifier': 665, 'impressions': ['A'], 'value': 1149},
#  {'identifier': 666, 'impressions': ['A'], 'value': 385},
#  {'identifier': 667, 'impressions': ['B', 'A'], 'value': 675},
#  {'identifier': 668, 'impressions': ['A'], 'value': 1478},
#  {'identifier': 669, 'impressions': ['A'], 'value': 231},
#  {'identifier': 670, 'impressions': ['C', 'A'], 'value': 960},
#  {'identifier': 671, 'impressions': ['C'], 'value': 1017},
#  {'identifier': 672, 'impressions': ['B'], 'value': 357},
#  {'identifier': 673, 'impressions': ['A'], 'value': 159},
#  {'identifier': 674, 'impressions': ['A'], 'value': 443},
#  {'identifier': 675, 'impressions': ['B'], 'value': 266},
#  {'identifier': 676, 'impressions': ['A'], 'value': 209},
#  {'identifier': 677, 'impressions': ['B', 'A'], 'value': 1189},
#  {'identifier': 678, 'impressions': ['B', 'A'], 'value': 1291},
#  {'identifier': 679, 'impressions': ['B', 'A'], 'value': 1196},
#  {'identifier': 680, 'impressions': ['B', 'A'], 'value': 1380},
#  {'identifier': 681, 'impressions': ['B', 'A'], 'value': 1963},
#  {'identifier': 682, 'impressions': ['B', 'A'], 'value': 1711},
#  {'identifier': 683, 'impressions': ['B', 'A'], 'value': 1825},
#  {'identifier': 684, 'impressions': ['B'], 'value': 879},
#  {'identifier': 685, 'impressions': ['A'], 'value': 3419},
#  {'identifier': 686, 'impressions': ['A'], 'value': 1340},
#  {'identifier': 687, 'impressions': ['A'], 'value': 1154},
#  {'identifier': 688, 'impressions': ['B', 'A'], 'value': 529},
#  {'identifier': 689, 'impressions': ['A'], 'value': 669},
#  {'identifier': 690, 'impressions': ['B', 'A'], 'value': 1686},
#  {'identifier': 691, 'impressions': ['B', 'A'], 'value': 2090},
#  {'identifier': 692, 'impressions': ['B', 'A'], 'value': 1676},
#  {'identifier': 693, 'impressions': ['C', 'B', 'A'], 'value': 2349},
#  {'identifier': 694, 'impressions': ['C', 'B'], 'value': 1049},
#  {'identifier': 695, 'impressions': ['C'], 'value': 918},
#  {'identifier': 696, 'impressions': ['A'], 'value': 2401},
#  {'identifier': 697, 'impressions': ['B', 'A'], 'value': 1747},
#  {'identifier': 698, 'impressions': ['B', 'A'], 'value': 1958},
#  {'identifier': 699, 'impressions': ['B', 'A'], 'value': 1819},
#  {'identifier': 700, 'impressions': ['B', 'A'], 'value': 2781},
#  {'identifier': 701, 'impressions': ['B'], 'value': 1713},
#  {'identifier': 702, 'impressions': ['A'], 'value': 607},
#  {'identifier': 703, 'impressions': ['C', 'B', 'A'], 'value': 2965},
#  {'identifier': 704, 'impressions': ['C', 'B', 'A'], 'value': 2835},
#  {'identifier': 705, 'impressions': ['C', 'B', 'A'], 'value': 3131},
#  {'identifier': 706, 'impressions': ['C', 'B', 'A'], 'value': 2313},
#  {'identifier': 707, 'impressions': ['C', 'B', 'A'], 'value': 2591},
#  {'identifier': 708, 'impressions': ['C', 'B'], 'value': 2041},
#  {'identifier': 709, 'impressions': ['B'], 'value': 1909},
#  {'identifier': 710, 'impressions': ['B', 'A'], 'value': 1571},
#  {'identifier': 711, 'impressions': ['B', 'A'], 'value': 1677},
#  {'identifier': 712, 'impressions': ['B', 'A'], 'value': 1402},
#  {'identifier': 713, 'impressions': ['B', 'A'], 'value': 1426},
#  {'identifier': 714, 'impressions': ['B', 'A'], 'value': 4042},
#  {'identifier': 715, 'impressions': ['B'], 'value': 1448},
#  {'identifier': 716, 'impressions': ['A'], 'value': 647},
#  {'identifier': 717, 'impressions': ['A'], 'value': 827},
#  {'identifier': 718, 'impressions': ['B', 'A'], 'value': 759},
#  {'identifier': 719, 'impressions': ['B'], 'value': 215},
#  {'identifier': 720, 'impressions': ['A'], 'value': 247},
#  {'identifier': 721, 'impressions': ['B', 'A'], 'value': 1696},
#  {'identifier': 722, 'impressions': ['B', 'A'], 'value': 2689},
#  {'identifier': 723, 'impressions': ['A'], 'value': 2496},
#  {'identifier': 724, 'impressions': ['B', 'A'], 'value': 3347},
#  {'identifier': 725, 'impressions': ['B', 'A'], 'value': 1553},
#  {'identifier': 726, 'impressions': ['C', 'B', 'A'], 'value': 1654},
#  {'identifier': 727, 'impressions': ['C', 'B', 'A'], 'value': 1635},
#  {'identifier': 728, 'impressions': ['C', 'B', 'A'], 'value': 1685},
#  {'identifier': 729, 'impressions': ['C', 'B'], 'value': 1407},
#  {'identifier': 730, 'impressions': ['B'], 'value': 705},
#  {'identifier': 731, 'impressions': ['A'], 'value': 246},
#  {'identifier': 732, 'impressions': ['C'], 'value': 96},
#  {'identifier': 733, 'impressions': ['A'], 'value': 0},
#  {'identifier': 734, 'impressions': ['C', 'B', 'A'], 'value': 3490},
#  {'identifier': 735, 'impressions': ['C', 'B', 'A'], 'value': 3669},
#  {'identifier': 736, 'impressions': ['C', 'B', 'A'], 'value': 3988},
#  {'identifier': 737, 'impressions': ['C', 'B', 'A'], 'value': 4715},
#  {'identifier': 738, 'impressions': ['C', 'B', 'A'], 'value': 4074},
#  {'identifier': 739, 'impressions': ['C', 'B', 'A'], 'value': 3690},
#  {'identifier': 740, 'impressions': ['C', 'B'], 'value': 2873},
#  {'identifier': 741, 'impressions': ['B'], 'value': 2601},
#  {'identifier': 742, 'impressions': ['B', 'A'], 'value': 2318},
#  {'identifier': 743, 'impressions': ['B', 'A'], 'value': 2381},
#  {'identifier': 744, 'impressions': ['A'], 'value': 2293},
#  {'identifier': 745, 'impressions': ['C', 'B', 'A'], 'value': 1144},
#  {'identifier': 746, 'impressions': ['C', 'B', 'A'], 'value': 1126},
#  {'identifier': 747, 'impressions': ['C', 'B', 'A'], 'value': 1044},
#  {'identifier': 748, 'impressions': ['C', 'B', 'A'], 'value': 733},
#  {'identifier': 749, 'impressions': ['C', 'B'], 'value': 389},
#  {'identifier': 750, 'impressions': ['B'], 'value': 351},
#  {'identifier': 751, 'impressions': ['C', 'B', 'A'], 'value': 1677},
#  {'identifier': 752, 'impressions': ['C', 'B', 'A'], 'value': 641},
#  {'identifier': 753, 'impressions': ['C', 'B', 'A'], 'value': 633},
#  {'identifier': 754, 'impressions': ['C', 'B'], 'value': 747},
#  {'identifier': 755, 'impressions': ['B'], 'value': 464},
#  {'identifier': 756, 'impressions': ['B', 'A'], 'value': 242},
#  {'identifier': 757, 'impressions': ['B', 'A'], 'value': 1460},
#  {'identifier': 758, 'impressions': ['B'], 'value': 639},
#  {'identifier': 759, 'impressions': ['A'], 'value': 1152},
#  {'identifier': 760, 'impressions': ['B', 'A'], 'value': 1230},
#  {'identifier': 761, 'impressions': ['B', 'A'], 'value': 628},
#  {'identifier': 762, 'impressions': ['A'], 'value': 702},
#  {'identifier': 763, 'impressions': ['C', 'B', 'A'], 'value': 2792},
#  {'identifier': 764, 'impressions': ['C', 'B', 'A'], 'value': 1914},
#  {'identifier': 765, 'impressions': ['C', 'B', 'A'], 'value': 1663},
#  {'identifier': 766, 'impressions': ['C', 'B'], 'value': 1389},
#  {'identifier': 767, 'impressions': ['B'], 'value': 1285},
#  {'identifier': 768, 'impressions': ['A'], 'value': 775},
#  {'identifier': 769, 'impressions': ['C', 'B', 'A'], 'value': 540},
#  {'identifier': 770, 'impressions': ['C', 'A'], 'value': 557},
#  {'identifier': 771, 'impressions': ['C'], 'value': 807},
#  {'identifier': 772, 'impressions': ['B', 'A'], 'value': 2002},
#  {'identifier': 773, 'impressions': ['B'], 'value': 914},
#  {'identifier': 774, 'impressions': ['B', 'A'], 'value': 530},
#  {'identifier': 775, 'impressions': ['A'], 'value': 1015},
#  {'identifier': 776, 'impressions': ['B', 'A'], 'value': 1250},
#  {'identifier': 777, 'impressions': ['B', 'A'], 'value': 1223},
#  {'identifier': 778, 'impressions': ['B'], 'value': 541},
#  {'identifier': 779, 'impressions': ['B', 'A'], 'value': 1887},
#  {'identifier': 780, 'impressions': ['B', 'A'], 'value': 694},
#  {'identifier': 781, 'impressions': ['B', 'A'], 'value': 745},
#  {'identifier': 782, 'impressions': ['B'], 'value': 388},
#  {'identifier': 783, 'impressions': ['A'], 'value': 2780},
#  {'identifier': 784, 'impressions': ['C', 'B', 'A'], 'value': 3065},
#  {'identifier': 785, 'impressions': ['C', 'B', 'A'], 'value': 3578},
#  {'identifier': 786, 'impressions': ['C', 'B', 'A'], 'value': 3118},
#  {'identifier': 787, 'impressions': ['C', 'B', 'A'], 'value': 3414},
#  {'identifier': 788, 'impressions': ['B', 'A'], 'value': 2730},
#  {'identifier': 789, 'impressions': ['B', 'A'], 'value': 2884},
#  {'identifier': 790, 'impressions': ['B'], 'value': 2030},
#  {'identifier': 791, 'impressions': ['A'], 'value': 745},
#  {'identifier': 792, 'impressions': ['B', 'A'], 'value': 87},
#  {'identifier': 793, 'impressions': ['A'], 'value': 18},
#  {'identifier': 794, 'impressions': ['B', 'A'], 'value': 2532},
#  {'identifier': 795, 'impressions': ['B', 'A'], 'value': 3130},
#  {'identifier': 796, 'impressions': ['C', 'B', 'A'], 'value': 4451},
#  {'identifier': 797, 'impressions': ['C', 'B'], 'value': 1965},
#  {'identifier': 798, 'impressions': ['B'], 'value': 1703},
#  {'identifier': 799, 'impressions': ['B', 'A'], 'value': 771},
#  {'identifier': 800, 'impressions': ['B', 'A'], 'value': 964},
#  {'identifier': 801, 'impressions': ['A'], 'value': 1338},
#  {'identifier': 802, 'impressions': ['B', 'A'], 'value': 604},
#  {'identifier': 803, 'impressions': ['B', 'A'], 'value': 256},
#  {'identifier': 804, 'impressions': ['B'], 'value': 189},
#  {'identifier': 805, 'impressions': ['B', 'A'], 'value': 697},
#  {'identifier': 806, 'impressions': ['A'], 'value': 623},
#  {'identifier': 807, 'impressions': ['C', 'A'], 'value': 2155},
#  {'identifier': 808, 'impressions': ['C', 'A'], 'value': 1569},
#  {'identifier': 809, 'impressions': ['C', 'A'], 'value': 1241},
#  {'identifier': 810, 'impressions': ['C'], 'value': 935},
#  {'identifier': 811, 'impressions': ['A'], 'value': 456},
#  {'identifier': 812, 'impressions': ['B'], 'value': 2492},
#  {'identifier': 813, 'impressions': ['A'], 'value': 247},
#  {'identifier': 814, 'impressions': ['B'], 'value': 656},
#  {'identifier': 815, 'impressions': ['A'], 'value': 58},
#  {'identifier': 816, 'impressions': ['B', 'A'], 'value': 886},
#  {'identifier': 817, 'impressions': ['B', 'A'], 'value': 1258},
#  {'identifier': 818, 'impressions': ['B', 'A'], 'value': 1925},
#  {'identifier': 819, 'impressions': ['B', 'A'], 'value': 911},
#  {'identifier': 820, 'impressions': ['B', 'A'], 'value': 789},
#  {'identifier': 821, 'impressions': ['B', 'A'], 'value': 931},
#  {'identifier': 822, 'impressions': ['A'], 'value': 996},
#  {'identifier': 823, 'impressions': ['A'], 'value': 1299},
#  {'identifier': 824, 'impressions': ['A'], 'value': 407},
#  {'identifier': 825, 'impressions': ['C', 'B', 'A'], 'value': 373},
#  {'identifier': 826, 'impressions': ['C', 'B', 'A'], 'value': 256},
#  {'identifier': 827, 'impressions': ['C', 'A'], 'value': 686},
#  {'identifier': 828, 'impressions': ['C'], 'value': 611},
#  {'identifier': 829, 'impressions': ['A'], 'value': 1029},
#  {'identifier': 830, 'impressions': ['B', 'A'], 'value': 947},
#  {'identifier': 831, 'impressions': ['B', 'A'], 'value': 975},
#  {'identifier': 832, 'impressions': ['B', 'A'], 'value': 886},
#  {'identifier': 833, 'impressions': ['B', 'A'], 'value': 1069},
#  {'identifier': 834, 'impressions': ['B'], 'value': 1288},
#  {'identifier': 835, 'impressions': ['A'], 'value': 368},
#  {'identifier': 836, 'impressions': ['B', 'A'], 'value': 1466},
#  {'identifier': 837, 'impressions': ['B', 'A'], 'value': 1284},
#  {'identifier': 838, 'impressions': ['C', 'A'], 'value': 2065},
#  {'identifier': 839, 'impressions': ['C'], 'value': 578},
#  {'identifier': 840, 'impressions': ['B', 'A'], 'value': 531},
#  {'identifier': 841, 'impressions': ['B', 'A'], 'value': 928},
#  {'identifier': 842, 'impressions': ['B'], 'value': 250},
#  {'identifier': 843, 'impressions': ['B', 'A'], 'value': 3093},
#  {'identifier': 844, 'impressions': ['B', 'A'], 'value': 1382},
#  {'identifier': 845, 'impressions': ['C', 'B', 'A'], 'value': 2065},
#  {'identifier': 846, 'impressions': ['C', 'B', 'A'], 'value': 852},
#  {'identifier': 847, 'impressions': ['C', 'A'], 'value': 719},
#  {'identifier': 848, 'impressions': ['C'], 'value': 585},
#  {'identifier': 849, 'impressions': ['B', 'A'], 'value': 467},
#  {'identifier': 850, 'impressions': ['B', 'A'], 'value': 614},
#  {'identifier': 851, 'impressions': ['A'], 'value': 692},
#  {'identifier': 852, 'impressions': ['B', 'A'], 'value': 2450},
#  {'identifier': 853, 'impressions': ['B', 'A'], 'value': 2259},
#  {'identifier': 854, 'impressions': ['B', 'A'], 'value': 2694},
#  {'identifier': 855, 'impressions': ['B', 'A'], 'value': 2065},
#  {'identifier': 856, 'impressions': ['B', 'A'], 'value': 1915},
#  {'identifier': 857, 'impressions': ['B', 'A'], 'value': 1562},
#  {'identifier': 858, 'impressions': ['B'], 'value': 609},
#  {'identifier': 859, 'impressions': ['A'], 'value': 35},
#  {'identifier': 860, 'impressions': ['A'], 'value': 1049},
#  {'identifier': 861, 'impressions': ['C', 'A'], 'value': 1034},
#  {'identifier': 862, 'impressions': ['C', 'B', 'A'], 'value': 1682},
#  {'identifier': 863, 'impressions': ['C', 'B', 'A'], 'value': 1231},
#  {'identifier': 864, 'impressions': ['C', 'A'], 'value': 1094},
#  {'identifier': 865, 'impressions': ['C'], 'value': 891},
#  {'identifier': 866, 'impressions': ['B', 'A'], 'value': 2141},
#  {'identifier': 867, 'impressions': ['B', 'A'], 'value': 860},
#  {'identifier': 868, 'impressions': ['C', 'B', 'A'], 'value': 1535},
#  {'identifier': 869, 'impressions': ['C', 'B'], 'value': 853},
#  {'identifier': 870, 'impressions': ['B'], 'value': 744},
#  {'identifier': 871, 'impressions': ['A'], 'value': 3774},
#  {'identifier': 872, 'impressions': ['B', 'A'], 'value': 685},
#  {'identifier': 873, 'impressions': ['B', 'A'], 'value': 1035},
#  {'identifier': 874, 'impressions': ['B'], 'value': 23},
#  {'identifier': 875, 'impressions': ['B'], 'value': 93},
#  {'identifier': 876, 'impressions': ['A'], 'value': 583},
#  {'identifier': 877, 'impressions': ['A'], 'value': 780},
#  {'identifier': 878, 'impressions': ['A'], 'value': 149},
#  {'identifier': 879, 'impressions': ['A'], 'value': 144},
#  {'identifier': 880, 'impressions': ['B', 'A'], 'value': 720},
#  {'identifier': 881, 'impressions': ['C', 'B', 'A'], 'value': 734},
#  {'identifier': 882, 'impressions': ['C', 'B', 'A'], 'value': 584},
#  {'identifier': 883, 'impressions': ['C', 'B', 'A'], 'value': 705},
#  {'identifier': 884, 'impressions': ['C', 'B', 'A'], 'value': 727},
#  {'identifier': 885, 'impressions': ['C', 'B', 'A'], 'value': 537},
#  {'identifier': 886, 'impressions': ['C', 'B', 'A'], 'value': 666},
#  {'identifier': 887, 'impressions': ['C', 'B'], 'value': 572},
#  {'identifier': 888, 'impressions': ['B'], 'value': 521},
#  {'identifier': 889, 'impressions': ['B'], 'value': 479},
#  {'identifier': 890, 'impressions': ['C', 'B', 'A'], 'value': 2123},
#  {'identifier': 891, 'impressions': ['C', 'B', 'A'], 'value': 620},
#  {'identifier': 892, 'impressions': ['C', 'B', 'A'], 'value': 818},
#  {'identifier': 893, 'impressions': ['C', 'B'], 'value': 921},
#  {'identifier': 894, 'impressions': ['B'], 'value': 638},
#  {'identifier': 895, 'impressions': ['C', 'A'], 'value': 1752},
#  {'identifier': 896, 'impressions': ['C'], 'value': 1441},
#  {'identifier': 897, 'impressions': ['B'], 'value': 47},
#  {'identifier': 898, 'impressions': ['A'], 'value': 567},
#  {'identifier': 899, 'impressions': ['B', 'A'], 'value': 753},
#  {'identifier': 900, 'impressions': ['B'], 'value': 876},
#  {'identifier': 901, 'impressions': ['B', 'A'], 'value': 749},
#  {'identifier': 902, 'impressions': ['B', 'A'], 'value': 681},
#  {'identifier': 903, 'impressions': ['A'], 'value': 1186},
#  {'identifier': 904, 'impressions': ['B', 'A'], 'value': 776},
#  {'identifier': 905, 'impressions': ['B', 'A'], 'value': 973},
#  {'identifier': 906, 'impressions': ['B', 'A'], 'value': 55},
#  {'identifier': 907, 'impressions': ['B', 'A'], 'value': 52},
#  {'identifier': 908, 'impressions': ['B'], 'value': 40},
#  {'identifier': 909, 'impressions': ['A'], 'value': 692},
#  {'identifier': 910, 'impressions': ['A'], 'value': 313},
#  {'identifier': 911, 'impressions': ['A'], 'value': 1437},
#  {'identifier': 912, 'impressions': ['B', 'A'], 'value': 3042},
#  {'identifier': 913, 'impressions': ['B', 'A'], 'value': 1836},
#  {'identifier': 914, 'impressions': ['B', 'A'], 'value': 1659},
#  {'identifier': 915, 'impressions': ['B', 'A'], 'value': 1156},
#  {'identifier': 916, 'impressions': ['C', 'A'], 'value': 2452},
#  {'identifier': 917, 'impressions': ['C'], 'value': 1406},
#  {'identifier': 918, 'impressions': ['B', 'A'], 'value': 2218},
#  {'identifier': 919, 'impressions': ['B', 'A'], 'value': 1209},
#  {'identifier': 920, 'impressions': ['C', 'A'], 'value': 1959},
#  {'identifier': 921, 'impressions': ['C', 'B', 'A'], 'value': 1215},
#  {'identifier': 922, 'impressions': ['C', 'B', 'A'], 'value': 1026},
#  {'identifier': 923, 'impressions': ['C', 'B'], 'value': 755},
#  {'identifier': 924, 'impressions': ['B'], 'value': 361},
#  {'identifier': 925, 'impressions': ['B', 'A'], 'value': 518},
#  {'identifier': 926, 'impressions': ['B', 'A'], 'value': 451},
#  {'identifier': 927, 'impressions': ['A'], 'value': 441},
#  {'identifier': 928, 'impressions': ['A'], 'value': 271},
#  {'identifier': 929, 'impressions': ['A'], 'value': 250},
#  {'identifier': 930, 'impressions': ['B', 'A'], 'value': 115},
#  {'identifier': 931, 'impressions': ['A'], 'value': 342},
#  {'identifier': 932, 'impressions': ['A'], 'value': 398},
#  {'identifier': 933, 'impressions': ['B', 'A'], 'value': 1858},
#  {'identifier': 934, 'impressions': ['A'], 'value': 1860},
#  {'identifier': 935, 'impressions': ['A'], 'value': 598},
#  {'identifier': 936, 'impressions': ['B', 'A'], 'value': 830},
#  {'identifier': 937, 'impressions': ['C', 'B', 'A'], 'value': 1553},
#  {'identifier': 938, 'impressions': ['C', 'B', 'A'], 'value': 998},
#  {'identifier': 939, 'impressions': ['C', 'B', 'A'], 'value': 811},
#  {'identifier': 940, 'impressions': ['C', 'B', 'A'], 'value': 937},
#  {'identifier': 941, 'impressions': ['C', 'B'], 'value': 678},
#  {'identifier': 942, 'impressions': ['B'], 'value': 592},
#  {'identifier': 943, 'impressions': ['B', 'A'], 'value': 453},
#  {'identifier': 944, 'impressions': ['B', 'A'], 'value': 415},
#  {'identifier': 945, 'impressions': ['B', 'A'], 'value': 649},
#  {'identifier': 946, 'impressions': ['B', 'A'], 'value': 837},
#  {'identifier': 947, 'impressions': ['B', 'A'], 'value': 744},
#  {'identifier': 948, 'impressions': ['A'], 'value': 740},
#  {'identifier': 949, 'impressions': ['B', 'A'], 'value': 1075},
#  {'identifier': 950, 'impressions': ['B', 'A'], 'value': 1011},
#  {'identifier': 951, 'impressions': ['B', 'A'], 'value': 1211},
#  {'identifier': 952, 'impressions': ['A'], 'value': 2496},
#  {'identifier': 953, 'impressions': ['A'], 'value': 1114},
#  {'identifier': 954, 'impressions': ['B', 'A'], 'value': 3208},
#  {'identifier': 955, 'impressions': ['B'], 'value': 861},
#  {'identifier': 956, 'impressions': ['B', 'A'], 'value': 510},
#  {'identifier': 957, 'impressions': ['B', 'A'], 'value': 797},
#  {'identifier': 958, 'impressions': ['B', 'A'], 'value': 416},
#  {'identifier': 959, 'impressions': ['B', 'A'], 'value': 430},
#  {'identifier': 960, 'impressions': ['B'], 'value': 351},
#  {'identifier': 961, 'impressions': ['C', 'B', 'A'], 'value': 1582},
#  {'identifier': 962, 'impressions': ['C', 'B', 'A'], 'value': 1287},
#  {'identifier': 963, 'impressions': ['C', 'B', 'A'], 'value': 663},
#  {'identifier': 964, 'impressions': ['C', 'B', 'A'], 'value': 113},
#  {'identifier': 965, 'impressions': ['C', 'B', 'A'], 'value': 54},
#  {'identifier': 966, 'impressions': ['C', 'B'], 'value': 3},
#  {'identifier': 967, 'impressions': ['B'], 'value': 3},
#  {'identifier': 968, 'impressions': ['A'], 'value': 834},
#  {'identifier': 969, 'impressions': ['A'], 'value': 484},
#  {'identifier': 970, 'impressions': ['A'], 'value': 222},
#  {'identifier': 971, 'impressions': ['B'], 'value': 55},
#  {'identifier': 972, 'impressions': ['A'], 'value': 599},
#  {'identifier': 973, 'impressions': ['C', 'A'], 'value': 496},
#  {'identifier': 974, 'impressions': ['C', 'A'], 'value': 425},
#  {'identifier': 975, 'impressions': ['A'], 'value': 573},
#  {'identifier': 976, 'impressions': ['A'], 'value': 718},
#  {'identifier': 977, 'impressions': ['A'], 'value': 245},
#  {'identifier': 978, 'impressions': ['A'], 'value': 529},
#  {'identifier': 979, 'impressions': ['A'], 'value': 457},
#  {'identifier': 980, 'impressions': ['A'], 'value': 1103},
#  {'identifier': 981, 'impressions': ['A'], 'value': 1678},
#  {'identifier': 982, 'impressions': ['B'], 'value': 987},
#  {'identifier': 983, 'impressions': ['C', 'B', 'A'], 'value': 1343},
#  {'identifier': 984, 'impressions': ['B', 'A'], 'value': 1406},
#  {'identifier': 985, 'impressions': ['B', 'A'], 'value': 1567},
#  {'identifier': 986, 'impressions': ['B', 'A'], 'value': 1448},
#  {'identifier': 987, 'impressions': ['B', 'A'], 'value': 1489},
#  {'identifier': 988, 'impressions': ['B'], 'value': 1431},
#  {'identifier': 989, 'impressions': ['A'], 'value': 2828},
#  {'identifier': 990, 'impressions': ['B', 'A'], 'value': 759},
#  {'identifier': 991, 'impressions': ['B', 'A'], 'value': 1638},
#  {'identifier': 992, 'impressions': ['B', 'A'], 'value': 1133},
#  {'identifier': 993, 'impressions': ['A'], 'value': 1372},
#  {'identifier': 994, 'impressions': ['C', 'B', 'A'], 'value': 1764},
#  {'identifier': 995, 'impressions': ['C', 'A'], 'value': 1917},
#  {'identifier': 996, 'impressions': ['C', 'B', 'A'], 'value': 3404},
#  {'identifier': 997, 'impressions': ['C', 'B', 'A'], 'value': 1492},
#  {'identifier': 998, 'impressions': ['C', 'B', 'A'], 'value': 1123},
#  {'identifier': 999, 'impressions': ['C', 'A'], 'value': 648},
#  {'identifier': 1000, 'impressions': ['C'], 'value': 350},
#  ...]
